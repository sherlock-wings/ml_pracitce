# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model
import matplotlib.pyplot as pyplot
from matplotlib import style
import pickle

data = pd.read_csv('C:\pcallahanProjects\ml_practice\data\studentGrades\student-mat.csv',
                   sep=';')
data = data[['G1', 'G2', 'G3', 'studytime', 'failures', 'absences']]

predict = "G3"
# what we predict with
X = np.array(data.drop([predict], axis=1))
# what we're trying to predict
Y = np.array(data[predict])

best = 0

for _ in range(10000):
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.1)
    linear = linear_model.LinearRegression()
    linear.fit(x_train, y_train)
    acc = linear.score(x_test, y_test)
    if acc>best:
        best = acc
        print("New best found! New best = " +str(best))
        with open("studentModel.pickle", "wb") as f:
            pickle.dump(linear, f)

style.use("ggplot")
p = 'absences'
pyplot.scatter(data[p], data['G3'])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()

# practice commit
# Out:
# New best found! New best = 0.8044531533505972
# New best found! New best = 0.8932234774289453
# New best found! New best = 0.9200048989668022
# New best found! New best = 0.9229375194873305
# New best found! New best = 0.9642726958734916
# New best found! New best = 0.9651753733175436
# New best found! New best = 0.9657389698903307
# New best found! New best = 0.9672191746108442
# New best found! New best = 0.9696342749813724
